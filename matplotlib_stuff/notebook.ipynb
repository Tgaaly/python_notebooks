# %%
import numpy as np
import matplotlib.pyplot as plt


data= {'cyclist': 14,
'golf-cart': 8935,
'large-vehicle': 251,
'motorcyclist': 14,
'pedestrian': 1567,
'pedestrian-with-object': 40,
'unknown/other': 1560,
'vehicle': 35672}

classes = data.keys()
x_pos = np.arange(len(classes))
# counts = [np.log(float(d)) for i, d in enumerate(data.values())]
counts = data.values()
indices = np.argsort(counts)
print indices, counts, type(counts)
counts = [counts[index] for index in indices]
classes = [classes[index] for index in indices]

# fig = plt.figure(figsize=(8, 9))
plt.bar(x_pos, counts, align='center', alpha=0.5, color='blue')
plt.xticks(x_pos, classes, rotation='vertical')
plt.ylabel('Number of Objects')
plt.title('Frequencies of Taxonomy')
plt.ylim(0, 36000)

 
plt.show()
# Out:
# [0 5 7 3 4 1 2 6] [14, 1567, 8935, 251, 1560, 14, 35672, 40] <type 'list'>
